# %% [markdown]
# # EX — Capstone Scoping Exercise
#
# This is a structured-thinking exercise (not code-heavy) to practice scoping an AI project
# from a rough stakeholder ask down to a shippable MVP.

# %% [markdown]
# ## Scenario
#
# > *"Our support team is drowning in tickets. Can you build something with AI to help?"*
#
# This is intentionally vague — real stakeholder asks usually are. Your job is to turn it
# into a scoped, buildable project.

# %% [markdown]
# ### TODO 1 — Discovery Questions
# Write 5 clarifying questions you'd ask the stakeholder before writing any code. (Think: volume, current process, success metric, risk tolerance, integration constraints.)

# %%
discovery_questions = [
    # TODO: fill in 5 questions
]
for q in discovery_questions:
    print("-", q)

# %% [markdown]
# <details><summary>Example answer</summary>
#
# - How many tickets come in per day, and what are the top 3 categories?
# - What does the current triage process look like, and where does it break down?
# - What would 'success' look like in 3 months — reduced response time? Fewer escalations?
# - What's the team's risk tolerance for an AI-suggested (vs. AI-automated) response?
# - What systems does this need to integrate with (helpdesk software, CRM)?
# </details>

# %% [markdown]
# ### TODO 2 — MVP Cut
# Given the answers might be: '500 tickets/day, mostly billing/technical/account; team wants faster triage, not full automation; must integrate with Zendesk' — write a one-paragraph MVP scope that is small enough to ship in 2-3 weeks.

# %%
mvp_scope = """
# TODO: write your MVP scope here as a string
"""
print(mvp_scope)

# %% [markdown]
# <details><summary>Example answer</summary>
#
# MVP: an automatic ticket **classifier** (billing/technical/account/other) that tags
# incoming Zendesk tickets and routes them to the right queue — no auto-response generation
# yet. Success metric: 85%+ classification accuracy vs. human labels on a held-out set, and
# a measurable drop in average time-to-first-routing. Auto-drafted responses and full
# automation are explicitly out of scope for the MVP — a 'nice to have' for phase 2.
# </details>

# %% [markdown]
# ### TODO 3 — Risks
# List 3 risks/unknowns for this MVP (data quality, cost, integration, etc.) and one mitigation for each.

# %%
risks = [
    # TODO: list (risk, mitigation) tuples
]
for r, m in risks:
    print(f"Risk: {r}\n  Mitigation: {m}")

# %% [markdown]
# <details><summary>Example answer</summary>
#
# - Risk: historical tickets aren't labeled for training data. Mitigation: start with a
#   rule/keyword baseline + few-shot LLM classification, collect human corrections to build
#   a labeled set over time.
# - Risk: misclassification routes urgent tickets to the wrong queue. Mitigation: add a
#   confidence threshold — low-confidence tickets go to a general queue instead of a guess.
# - Risk: cost scales with ticket volume if using a paid LLM API per ticket. Mitigation:
#   cache/batch classification, evaluate a cheaper model tier before defaulting to the largest.
# </details>

# %% [markdown]
# ## Key Takeaways
# - A vague ask needs discovery questions before any scoping — don't skip straight to a solution.
# - Writing the MVP cut *before* coding prevents scope creep.
# - Every AI project plan should explicitly name its risks and mitigations, not just the happy path.
