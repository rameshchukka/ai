# %%
# accessor & murator using setter and getter methods
class Person:
    def __init__(self, name, age):
        self.__name = name  # Private attribute (by convention)
        self._age = age
    # Accessor (Getter)
    def get_name(self):
        return self.__name
    # Mutator (Setter)
    def set_name(self, name):
        self.__name = name

# Using accessors and mutators
person = Person("John", 25)
print(person.get_name())  # Accessor: Output "John“

person.set_name("Jesus")
print(person.get_name())
# Out:
# John
# Jesus

# %%
# accessor & murator using Properties
class Person:
    def __init__(self, name, age):
        self.__name = name
        self._age = age
    @property
    def name(self):
        return self.__name
    @name.setter
    def name(self, value):
        self.__name = value

# Using @property as getter and setter
person = Person("John", 25)
print(person.name)  # Output: "John"
person.name = "jesus"
print(person.name)
# Out:
# John
# jesus

# %%
class Order:
    def __init__(self, order_id):
        self.order_id = order_id
        self.items = []

    def add_item(self, name, price, quantity):
        item = self.Item(name, price, quantity)  # Create an item using the inner class
        self.items.append(item)

    def get_total_price(self):
        return sum([item.price * item.quantity for item in self.items])  
# Inner class representing an item in the order
    class Item:
        def __init__(self, name, price, quantity):
            self.name = name
            self.price = price
            self.quantity = quantity


order = Order("ORD1234")  # Creating an order object
order.add_item("Laptop", 1500, 2)  # Adding items to the order
order.add_item("Mouse", 20, 5)

order.get_total_price()

# item1 = order.Item("name", 10, 2)
# Out:
# 3100

# %%
class Product:
    name ="iPhone"
    def set_item(self,newname):
        self.name = newname

    def displayitem(self): 
        print("Item in the cart is " + self.name)
        print(f"Item in the cart is {self.name}") # Lets see here how f-string works here
        
        

p1= Product()
p1.set_item("watch rolex")
p1.displayitem()
# Out:
# Item in the cart is watch rolex
# Item in the cart is watch rolex
