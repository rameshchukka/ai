# %%
# very basic class creation
class Engine:

    def start_engine(self):
        print("engine is started")


eng= Engine()
eng.start_engine()

# %%
class ClassName:

    interest = 0.01
    

    def fucntion_name(self):
        print("my first fucntion")

    def cal_interest(principle):
        return principle* ClassName.interest 

#####################################################################################

name = "prudvi"

refvar= ClassName()

refvar2 = ClassName()

refvar.fucntion_name()

ClassName.cal_interest(10000)

# %%
class BankingApp:

    def __init__(self,myprinciple,myinterestrate):
        self.principle = myprinciple
        self.interestrate = myinterestrate

    def calc_interest(self):
        return self.principle * self.interestrate
    
    def give_loan(self):
        print("gave you loan")

#######################################################################

idbibak= BankingApp(10000,0.1)

idbibak.calc_interest()



# hdfcbnk= BankingApp()

# idfcbnk= BankingApp()


# print(hdfcbnk.calc_interest(100000,0.1))

# print(idfcbnk.calc_interest(200000,0.15))

# %%
class Dog:
    # Class attribute (shared by all instances)
    species = "Canis familiaris"

    #constructor
    def __init__(self, name):
        self.name = name  # Instance attribute

    # Class method
    @classmethod
    def species_info(cls):
        return f"All dogs are of species {cls.species}"
    
    # instance Method
    def foodhabit(self,eatingspeed):
        print("eating " + eatingspeed + " is a foodhabit of ", self.name)

####################################################################################

dogobj= Dog("pinky")
dogobj.foodhabit("fast")

dogobj= Dog("james")
dogobj.foodhabit("slow") # calling instance Method

print (Dog.species_info()) # calling class Method
