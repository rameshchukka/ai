# %% [markdown]
# # Lesson01: Python Fundamentals
#
# Converted from the original `.py` scripts in this lesson. Each section below is one original script, shown exactly as written, as its own runnable cell. The original `.py` files (and any data files they depend on) are kept in this same folder, so relative imports and relative file paths still work.

# %% [markdown]
# ## `HelloWorld.py` -- Hello World

# %%
print('Hello World')

# %% [markdown]
# ## `RuleBreakingVariables.py` -- Rule Breaking Variables

# %%
dollars ='lots of money'
pass_word = 'Eureka'
my_items = ['bag', 'racket', 'watch']
ten_thousand = 10000
IMPORT = 'bringing goods into the country'
Tupac = 'All Eyez on Me'

print('Yay error free')

# %% [markdown]
# ## `formatName.py` -- Format Name

# %% [markdown]
# > ⚠️ **Runs differently in Jupyter.** This script reads `sys.argv[1]`/`sys.argv[2]` -- command-line arguments. Running the cell as-is in Jupyter will raise an `IndexError` because the notebook kernel has no extra arguments to give it. To see it work as intended, run it from a terminal instead: `python formatName.py John Doe`.

# %%
import sys

print('------------------------')
print('First Name:',sys.argv[1])
print('Last Name:',sys.argv[2])
print('------------------------')
