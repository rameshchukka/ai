# %% [markdown]
# # Lesson07: Python Fundamentals
#
# Converted from the original `.py` scripts in this lesson. Each section below is one original script, shown exactly as written, as its own runnable cell. The original `.py` files (and any data files they depend on) are kept in this same folder, so relative imports and relative file paths still work.

# %% [markdown]
# ## `dictionary.py` -- Dictionary

# %%
# create a dictionary in 2 different ways
scores = dict(
    Bob=20,
    Alice=23
)

nicknames = {'Bob': 'Bobby', 'Alice': 'Ally'}

# print dictionary
print(scores)
print(nicknames)
# read a specific value from a dictionary
print(scores['Alice'])
scores['Cam'] = 22
scores['Cam'] += 1
print(scores)
# write a specific value to a dictionary

# %% [markdown]
# ## `dictionaryIteration.py` -- Dictionary Iteration

# %%
scores = {
    'Bob': 20,
    'Alice': 23,
    'Jim': 22,
    'Xavier': 0
}

for name in scores:
    print('The score of',name,'is',scores[name])

# %% [markdown]
# ## `dictionaryMethods.py` -- Dictionary Methods

# %%
letters = ['a', 'b', 'c', 'd', 'e']

scores = {
    'Bob': 20,
    'Alice': 23,
    'Jim': 22,
}
'''
dict.copy()
dict.update()
dict.keys()  # lets you know what to query
keys = dict.fromkeys(list)
scores.get('key')
min() max() and len()
dict.pop()
dict.popitem())
dict.clear()
'''

# %% [markdown]
# ## `dictionaryOperations.py` -- Dictionary Operations

# %%
scores = {
    'Bob': 20,
    'Alice': 23,
    'Jim': 22,
    'Xavier': 0
}
print('Bob' in scores)
scores['Bob'] += 1

print(scores)

# %% [markdown]
# ## `dictionary_masher.py` -- Dictionary Masher

# %%
def dictionary_masher(dict_a, dict_b):
  for key, value in dict_b.items():
    if key not in dict_a:
      dict_a[key] = value
      
  return dict_a

# %% [markdown]
# ## `orderedDictionary.py` -- Ordered Dictionary

# %%
from collections import OrderedDict

a = OrderedDict(name='Zeus', role='god', age='old')
b = OrderedDict(name='Zeus', age='old', role='god')

print(a == b)

c = {'name': 'Zeus', 'role': 'god', 'age': 'old'}
d = {'age': 'old', 'name': 'Zeus', 'role': 'god'}

print(a == c)

print(c == d)

# %% [markdown]
# ## `orderedDictionaryFunctions.py` -- Ordered Dictionary Functions

# %%
from collections import OrderedDict

a = OrderedDict(name='Zeus', role='god', home='Olympus')
b = {}
dictionary_functions = dir(b)
OrderedDict_functions = dir(a)

#print(dictionary_functions)

for f in OrderedDict_functions:
    if f not in dictionary_functions:
        print(f)

# %% [markdown]
# ## `sentenceAnalyzer.py` -- Sentence Analyzer

# %%
text = """
The programming language Python was conceived in the late 1980s, and its implementation was started in December 1989
by Guido van Rossum at CWI in the Netherlands as a successor to ABC capable of exception handling and interfacing with 
the Amoeba operating system. Van Rossum is Python's principal author, and his continuing central role in deciding 
the direction of Python is reflected in the title given to him by the Python community, Benevolent Dictator for Life 
(BDFL). Python was named for the BBC TV show Monty Python's Flying Circus.
"""


def text_analyzer(text):
    solution = {}
    for c in text:
        c = c.lower()
        if c is not ' ':
            if c in solution:
                solution[c] += 1
            else:
                solution[c] = 1
    return solution


letterFrequencies = text_analyzer(text)

for c in letterFrequencies:
    print('The letter', c, 'repeats', letterFrequencies[c], 'times')

# %% [markdown]
# ## `set.py` -- Set

# %%
# create 2 sets
a = {1,2,3}
b = {3,4,5}

# print elements
print(a)
# iterate through sets
for item in a:
    print(item)
# add elements
a.add(4)
print(a)
a.update(b)
print(a)
# remove items from sets 3 different ways
a.remove(5)
a.discard(4)
print(a.pop())
print(a)

# %% [markdown]
# ## `setOperations.py` -- Set Operations

# %%
a = {1, 2, 3}
b = {3, 4, 5}

# A union B
print('a union b')
print(a.union(b))
print(a | b)

# A intersection B
print('a intersection b')
print(a.intersection(b))
print(a & b)
# A equals to B
print(a == b)

# Subsets and supersets
print('subsets and supersets')
print(a.issubset(b))
print(b.issuperset(a))
b.update(a)
print(b)
print(a.issubset(b))
print(b.issuperset(a))

# %% [markdown]
# ## `set_maker.py` -- Set Maker

# %%
def set_maker(the_list):
  return set(the_list)

# %% [markdown]
# ## `test.py` -- Test

# %% [markdown]
# > ⚠️ **This appears to be leftover scratch code**, not a real lesson example -- it references a variable `a` that's never defined anywhere, so it always raises `NameError`. Included for completeness (it was in the original repo), but there's nothing to learn from this one specifically -- see the other files in this lesson instead.

# %%
print(any(a))
